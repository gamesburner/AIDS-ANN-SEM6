# %% [markdown]
# **ANN PR11**

# %% [markdown]
# **TensorFlow/Pytorch implementation of CNN**

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\cds\software\ananconda_navigator\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\roaming\python\python313\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\cds\software\ananconda_navigator\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\cds\software\ananconda_navigator\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\cds\software\ananconda_navigator\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\cds\software\ananconda_navigator\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in d:\cds\software\ananconda_navigator\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\cds\software\ananconda_navigator\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\cds\software\ananconda_navigator\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\cds\software\ananconda_navigator\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train/ 255.0
X_test  = X_test/ 255.0
y_train, y_test = to_categorical(y_train), to_categorical(y_test)

# Model
model = tf.keras.Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    Flatten(),
    Dense(64,  activation='relu'),
    Dense(10,  activation='softmax')
])

# Compile + Train + Evaluate
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=64)

loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# D:\CDS\SOFTWARE\ANANCONDA_NAVIGATOR\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 59s 58ms/step - accuracy: 0.9460 - loss: 0.1793
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 52s 55ms/step - accuracy: 0.9842 - loss: 0.0504
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 59ms/step - accuracy: 0.9882 - loss: 0.0363
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 57ms/step - accuracy: 0.9910 - loss: 0.0275
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 55s 59ms/step - accuracy: 0.9928 - loss: 0.0223
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 53s 56ms/step - accuracy: 0.9939 - loss: 0.0189
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 54s 58ms/step - accuracy: 0.9949 - loss: 0.0150
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 50s 53ms/step - accuracy: 0.9952 - loss: 0.0128
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 52s 55ms/step - accuracy: 0.9965 - loss: 0.0111
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 53ms/step - accuracy: 0.9969 - loss: 0.0092
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9901 - loss: 0.0408
# Accuracy: 0.9901000261306763
